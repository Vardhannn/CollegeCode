# %%
import pandas as pd

data = pd.read_csv("iris.csv")
data = pd.DataFrame(data)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score

acc = accuracy_score(y_pred,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import classification_report,confusion_matrix

cla = classification_report(y_pred,y_test)

conf = confusion_matrix(y_pred,y_test)

import seaborn as sns

sns.heatmap(conf,annot = True)
# Out:
# <Axes: >

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#                                               0.0/293.3 kB ? eta -:--:--
#      ---------------                        122.9/293.3 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lokesh nimmakayala\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#visualizing tree

from sklearn import tree

fn = data.columns
cn =  data.iloc[:,-1].unique()

tree.plot_tree(model,filled = True,feature_names = fn,class_names = cn)
# Out:
# [Text(0.5555555555555556, 0.9285714285714286, 'petal_width <= 0.8\ngini = 0.664\nsamples = 120\nvalue = [42, 35, 43]\nclass = virginica'),
#  Text(0.4444444444444444, 0.7857142857142857, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]\nclass = setosa'),
#  Text(0.6666666666666666, 0.7857142857142857, 'petal_width <= 1.75\ngini = 0.495\nsamples = 78\nvalue = [0, 35, 43]\nclass = virginica'),
#  Text(0.5555555555555556, 0.6428571428571429, 'petal_length <= 5.35\ngini = 0.184\nsamples = 39\nvalue = [0, 35, 4]\nclass = versicolor'),
#  Text(0.4444444444444444, 0.5, 'sepal_length <= 4.95\ngini = 0.102\nsamples = 37\nvalue = [0, 35, 2]\nclass = versicolor'),
#  Text(0.2222222222222222, 0.35714285714285715, 'petal_length <= 3.9\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.1111111111111111, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.6666666666666666, 0.35714285714285715, 'petal_length <= 4.95\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(0.5555555555555556, 0.21428571428571427, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(0.7777777777777778, 0.21428571428571427, 'petal_width <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(0.6666666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.8888888888888888, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.7777777777777778, 0.6428571428571429, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]\nclass = virginica')]

# %%
fn
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
